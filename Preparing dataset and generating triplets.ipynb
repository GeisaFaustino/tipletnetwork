# %% [markdown]
# # Preparing dataset and generating triplets

# %% [markdown]
# ## Grouping images by person id and saving this mapping in a csv file

# %% [markdown]
# **About data set**
#
# This is a public data set download from https://cedar.buffalo.edu/NIJ/data/signatures.rar.
# 1. Folder full_forg: Contains 1320 forgery signatures (24 forgeries for each of 55 writers).
# 2. Folder full_org: Contains 1320 genuine signatures (24 genuines for each of 55 writers).
#
# Filename patern:
#
# **original_X_Y.png** and **forgeries_X_Y.png**
# * X - ID number of a person who has done the signature.
# * Y - Image smaple number
#
# For example, the file with name *original_1_6.png* is the 6th signature sample of person 1 and it is a genuine signature.
# On the other, the fine with name *forgeries_1_4.png* is the 4th signature sample of person 1 and it is a forged signature.

# %%
genuine_signatures_path = '../../dataset/signatures/full_org/'
forged_signatures_path = '../../dataset/signatures/full_forg/'

# %%
def chuncks( input_list, n ):
    # For item i in a range that is a length of l,
    for i in range(0, len(input_list), n):
        # Create an index range for l of n items:
        yield input_list[i:i+n]

# %%
from os import walk

forged_signatures = []
genuine_signatures = []

n = 24

for (dirpath, dirnames, filenames) in walk(forged_signatures_path):
    forged_signatures.extend(filenames)
    break

for (dirpath, dirnames, filenames) in walk(genuine_signatures_path):
    genuine_signatures.extend(filenames)
    break

# Removing last element because it is the 'Thumbs.db' file
forged_signatures = forged_signatures[:-1]
genuine_signatures = genuine_signatures[:-1]

genuine_signatures = list( chuncks( genuine_signatures, n) )
forged_signatures = list( chuncks(forged_signatures, n) )

# %%
print( 'forged_signatures:', len(forged_signatures), ', genuine_signatures:', len(genuine_signatures)  )
# Out:
# forged_signatures: 55 , genuine_signatures: 55

# %%
import pandas as pd

sample_signatures_df = pd.DataFrame( columns = ['PersonID', 'GenuineSignaturesSample', 'ForgedSignaturesSamples'] )

for i in range( len(forged_signatures) ):
    sample_signatures_df.loc[ int(i), ['PersonID', 'GenuineSignaturesSample', 'ForgedSignaturesSamples'] ] = [ i, genuine_signatures[i], forged_signatures[i] ]
                                                                                             
sample_signatures_df.sort_index( inplace = True )

# %%
sample_signatures_df.head()
# Out:
#   PersonID                            GenuineSignaturesSample  \
# 0        0  [original_10_1.png, original_10_10.png, origin...
# 1        1  [original_11_1.png, original_11_10.png, origin...
# 2        2  [original_12_1.png, original_12_10.png, origin...
# 3        3  [original_13_1.png, original_13_10.png, origin...
# 4        4  [original_14_1.png, original_14_10.png, origin...
#
#                              ForgedSignaturesSamples
# 0  [forgeries_10_1.png, forgeries_10_10.png, forg...
# 1  [forgeries_11_1.png, forgeries_11_10.png, forg...
# 2  [forgeries_12_1.png, forgeries_12_10.png, forg...
# 3  [forgeries_13_1.png, forgeries_13_10.png, forg...
# 4  [forgeries_14_1.png, forgeries_14_10.png, forg...

# %%
sample_signatures_df
# Out:
#    PersonID                            GenuineSignaturesSample  \
# 0         0  [original_10_1.png, original_10_10.png, origin...
# 1         1  [original_11_1.png, original_11_10.png, origin...
# 2         2  [original_12_1.png, original_12_10.png, origin...
# 3         3  [original_13_1.png, original_13_10.png, origin...
# 4         4  [original_14_1.png, original_14_10.png, origin...
# 5         5  [original_15_1.png, original_15_10.png, origin...
# 6         6  [original_16_1.png, original_16_10.png, origin...
# 7         7  [original_17_1.png, original_17_10.png, origin...
# 8         8  [original_18_1.png, original_18_10.png, origin...
# 9         9  [original_19_1.png, original_19_10.png, origin...
# 10       10  [original_1_1.png, original_1_10.png, original...
# 11       11  [original_20_1.png, original_20_10.png, origin...
# 12       12  [original_21_1.png, original_21_10.png, origin...
# 13       13  [original_22_1.png, original_22_10.png, origin...
# 14       14  [original_23_1.png, original_23_10.png, origin...
# 15       15  [original_24_1.png, original_24_10.png, origin...
# 16       16  [original_25_1.png, original_25_10.png, origin...
# 17       17  [original_26_1.png, original_26_10.png, origin...
# 18       18  [original_27_1.png, original_27_10.png, origin...
# 19       19  [original_28_1.png, original_28_10.png, origin...
# 20       20  [original_29_1.png, original_29_10.png, origin...
# 21       21  [original_2_1.png, original_2_10.png, original...
# 22       22  [original_30_1.png, original_30_10.png, origin...
# 23       23  [original_31_1.png, original_31_10.png, origin...
# 24       24  [original_32_1.png, original_32_10.png, origin...
# 25       25  [original_33_1.png, original_33_10.png, origin...
# 26       26  [original_34_1.png, original_34_10.png, origin...
# 27       27  [original_35_1.png, original_35_10.png, origin...
# 28       28  [original_36_1.png, original_36_10.png, origin...
# 29       29  [original_37_1.png, original_37_10.png, origin...
# 30       30  [original_38_1.png, original_38_10.png, origin...
# 31       31  [original_39_1.png, original_39_10.png, origin...
# 32       32  [original_3_1.png, original_3_10.png, original...
# 33       33  [original_40_1.png, original_40_10.png, origin...
# 34       34  [original_41_1.png, original_41_10.png, origin...
# 35       35  [original_42_1.png, original_42_10.png, origin...
# 36       36  [original_43_1.png, original_43_10.png, origin...
# 37       37  [original_44_1.png, original_44_10.png, origin...
# 38       38  [original_45_1.png, original_45_10.png, origin...
# 39       39  [original_46_1.png, original_46_10.png, origin...
# 40       40  [original_47_1.png, original_47_10.png, origin...
# 41       41  [original_48_1.png, original_48_10.png, origin...
# 42       42  [original_49_1.png, original_49_10.png, origin...
# 43       43  [original_4_1.png, original_4_10.png, original...
# 44       44  [original_50_1.png, original_50_10.png, origin...
# 45       45  [original_51_1.png, original_51_10.png, origin...
# 46       46  [original_52_1.png, original_52_10.png, origin...
# 47       47  [original_53_1.png, original_53_10.png, origin...
# 48       48  [original_54_1.png, original_54_10.png, origin...
# 49       49  [original_55_1.png, original_55_10.png, origin...
# 50       50  [original_5_1.png, original_5_10.png, original...
# 51       51  [original_6_1.png, original_6_10.png, original...
# 52       52  [original_7_1.png, original_7_10.png, original...
# 53       53  [original_8_1.png, original_8_10.png, original...
# 54       54  [original_9_1.png, original_9_10.png, original...
#
#                               ForgedSignaturesSamples
# 0   [forgeries_10_1.png, forgeries_10_10.png, forg...
# 1   [forgeries_11_1.png, forgeries_11_10.png, forg...
# 2   [forgeries_12_1.png, forgeries_12_10.png, forg...
# 3   [forgeries_13_1.png, forgeries_13_10.png, forg...
# 4   [forgeries_14_1.png, forgeries_14_10.png, forg...
# 5   [forgeries_15_1.png, forgeries_15_10.png, forg...
# 6   [forgeries_16_1.png, forgeries_16_10.png, forg...
# 7   [forgeries_17_1.png, forgeries_17_10.png, forg...
# 8   [forgeries_18_1.png, forgeries_18_10.png, forg...
# 9   [forgeries_19_1.png, forgeries_19_10.png, forg...
# 10  [forgeries_1_1.png, forgeries_1_10.png, forger...
# 11  [forgeries_20_1.png, forgeries_20_10.png, forg...
# 12  [forgeries_21_1.png, forgeries_21_10.png, forg...
# 13  [forgeries_22_1.png, forgeries_22_10.png, forg...
# 14  [forgeries_23_1.png, forgeries_23_10.png, forg...
# 15  [forgeries_24_1.png, forgeries_24_10.png, forg...
# 16  [forgeries_25_1.png, forgeries_25_10.png, forg...
# 17  [forgeries_26_1.png, forgeries_26_10.png, forg...
# 18  [forgeries_27_1.png, forgeries_27_10.png, forg...
# 19  [forgeries_28_1.png, forgeries_28_10.png, forg...
# 20  [forgeries_29_1.png, forgeries_29_10.png, forg...
# 21  [forgeries_2_1.png, forgeries_2_10.png, forger...
# 22  [forgeries_30_1.png, forgeries_30_10.png, forg...
# 23  [forgeries_31_1.png, forgeries_31_10.png, forg...
# 24  [forgeries_32_1.png, forgeries_32_10.png, forg...
# 25  [forgeries_33_1.png, forgeries_33_10.png, forg...
# 26  [forgeries_34_1.png, forgeries_34_10.png, forg...
# 27  [forgeries_35_1.png, forgeries_35_10.png, forg...
# 28  [forgeries_36_1.png, forgeries_36_10.png, forg...
# 29  [forgeries_37_1.png, forgeries_37_10.png, forg...
# 30  [forgeries_38_1.png, forgeries_38_10.png, forg...
# 31  [forgeries_39_1.png, forgeries_39_10.png, forg...
# 32  [forgeries_3_1.png, forgeries_3_10.png, forger...
# 33  [forgeries_40_1.png, forgeries_40_10.png, forg...
# 34  [forgeries_41_1.png, forgeries_41_10.png, forg...
# 35  [forgeries_42_1.png, forgeries_42_10.png, forg...
# 36  [forgeries_43_1.png, forgeries_43_10.png, forg...
# 37  [forgeries_44_1.png, forgeries_44_10.png, forg...
# 38  [forgeries_45_1.png, forgeries_45_10.png, forg...
# 39  [forgeries_46_1.png, forgeries_46_10.png, forg...
# 40  [forgeries_47_1.png, forgeries_47_10.png, forg...
# 41  [forgeries_48_1.png, forgeries_48_10.png, forg...
# 42  [forgeries_49_1.png, forgeries_49_10.png, forg...
# 43  [forgeries_4_1.png, forgeries_4_10.png, forger...
# 44  [forgeries_50_1.png, forgeries_50_10.png, forg...
# 45  [forgeries_51_1.png, forgeries_51_10.png, forg...
# 46  [forgeries_52_1.png, forgeries_52_10.png, forg...
# 47  [forgeries_53_1.png, forgeries_53_10.png, forg...
# 48  [forgeries_54_1.png, forgeries_54_10.png, forg...
# 49  [forgeries_55_1.png, forgeries_55_10.png, forg...
# 50  [forgeries_5_1.png, forgeries_5_10.png, forger...
# 51  [forgeries_6_1.png, forgeries_6_10.png, forger...
# 52  [forgeries_7_1.png, forgeries_7_10.png, forger...
# 53  [forgeries_8_1.png, forgeries_8_10.png, forger...
# 54  [forgeries_9_1.png, forgeries_9_10.png, forger...

# %%
# Convert a list of strings into one string using specified separator
def to_one_string( list_of_string, separator = ","):
    return separator.join(list_of_string)

# %%
sample_signatures_df.GenuineSignaturesSample = sample_signatures_df.GenuineSignaturesSample.apply( to_one_string )

# %%
sample_signatures_df.ForgedSignaturesSamples = sample_signatures_df.ForgedSignaturesSamples.apply( to_one_string )

# %%
sample_signatures_df.head()
# Out:
#   PersonID                            GenuineSignaturesSample  \
# 0        0  original_10_1.png,original_10_10.png,original_...
# 1        1  original_11_1.png,original_11_10.png,original_...
# 2        2  original_12_1.png,original_12_10.png,original_...
# 3        3  original_13_1.png,original_13_10.png,original_...
# 4        4  original_14_1.png,original_14_10.png,original_...
#
#                              ForgedSignaturesSamples
# 0  forgeries_10_1.png,forgeries_10_10.png,forgeri...
# 1  forgeries_11_1.png,forgeries_11_10.png,forgeri...
# 2  forgeries_12_1.png,forgeries_12_10.png,forgeri...
# 3  forgeries_13_1.png,forgeries_13_10.png,forgeri...
# 4  forgeries_14_1.png,forgeries_14_10.png,forgeri...

# %%
sample_signatures_df.to_csv("../../dataset/signatures/sample_signatures.csv", ',', index = False )

# %% [markdown]
# ## Generating triplets
#
# A triplet is composed of one achor (A), one positive sample (P) and a negative sample (N).
#
# Reference: https://omoindrot.github.io/triplet-loss

# %%
! pip install more-itertools
# Out:
# Requirement already satisfied: more-itertools in c:\users\gefausti\appdata\local\continuum\anaconda3\envs\ml-env-py37\lib\site-packages (6.0.0)

# %%
import itertools
import numpy as np

r = 2
combinations = list( itertools.combinations( range(3), r) ) 
permutations = list( itertools. permutations( range(3), r) )

print( 'combinations:', combinations )
print( 'permutations',  permutations )
# Out:
# combinations: [(0, 1), (0, 2), (1, 2)]
# permutations [(0, 1), (0, 2), (1, 0), (1, 2), (2, 0), (2, 1)]

# %% [markdown]
# **Note:** Given that we are dealing with two different lists, genuine and forged signatures respectively,
# d( genuine[0], genuine[1] ) != distance( genuine[1], forged[0] ).
# So, we can make triplets like these:
# * (0, 1, 1), (0, 2, 2), ..., (0, 23, 23)
# * (1, 0, 0), (1, 2, 2), ..., (1, 23, 23)
# * (2, 3, 3), (2, 4, 4), ..., (2, 23, 23)
# * ...
# * (23, 0, 0), (23, 1, 1), ..., (23, 22, 22)

# %%
permutations = list( itertools.permutations( range(24), 2) ) 
permutations.sort()
print( len(permutations) )
# Out:
# 552

# %%
from tqdm import tqdm

triplets = []

for idx in tqdm(sample_signatures_df.index):
    
    # Getting signature samples
    genuine_signatures = sample_signatures_df.GenuineSignaturesSample[idx].split(',')
    forged_signatures = sample_signatures_df.ForgedSignaturesSamples[idx].split(',')
    
    if( len(genuine_signatures) != len(forged_signatures) ):
        print( "ERROR: Set with diferent sizes.")
        continue
    
    # Making triples
    for p in permutations:
        # triple = (Anchor, Positive, Negative)
        triplet = ( genuine_signatures[p[0]], genuine_signatures[p[1]], forged_signatures[p[1]] )
        triplets.append( triplet )
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 55/55 [00:00<00:00, 1277.62it/s]

# %%
triplets[:10]
# Out:
# [('original_10_1.png', 'original_10_10.png', 'forgeries_10_10.png'),
#  ('original_10_1.png', 'original_10_11.png', 'forgeries_10_11.png'),
#  ('original_10_1.png', 'original_10_12.png', 'forgeries_10_12.png'),
#  ('original_10_1.png', 'original_10_13.png', 'forgeries_10_13.png'),
#  ('original_10_1.png', 'original_10_14.png', 'forgeries_10_14.png'),
#  ('original_10_1.png', 'original_10_15.png', 'forgeries_10_15.png'),
#  ('original_10_1.png', 'original_10_16.png', 'forgeries_10_16.png'),
#  ('original_10_1.png', 'original_10_17.png', 'forgeries_10_17.png'),
#  ('original_10_1.png', 'original_10_18.png', 'forgeries_10_18.png'),
#  ('original_10_1.png', 'original_10_19.png', 'forgeries_10_19.png')]

# %%
print( "Number of triplets:", len(triplets) )
# Out:
# Number of triplets: 30360

# %% [markdown]
# **Splitting triplets list into random train and test subsets**

# %%
from sklearn.model_selection import train_test_split

y = np.zeros( len(triplets) )
X_train, X_test, _, _ = train_test_split( triplets, y, test_size=0.33, random_state=42)

# %%
print( "Number of triplets for training:", len(X_train) )
print( "Number of triplets for testing:", len(X_test) )
# Out:
# Number of triplets for training: 20341
# Number of triplets for testing: 10019

# %% [markdown]
# **Saving training and testing datasets in csv files**

# %%
import csv

with open('../../dataset/signatures/X_train.csv', 'w') as csv_file:
    file = csv.writer( csv_file )
    file.writerow( ['Anchor', 'Positive', 'Negative'] )
    file.writerows(X_train)
    
with open('../../dataset/signatures/X_test.csv', 'w') as csv_file:
    file = csv.writer( csv_file )
    file.writerow( ['Anchor', 'Positive', 'Negative'] )
    file.writerows(X_test)

# %%
pd.read_csv( '../../dataset/signatures/X_train.csv' ).head()
# Out:
#                Anchor            Positive             Negative
# 0  original_14_17.png   original_14_1.png   forgeries_14_1.png
# 1    original_6_4.png    original_6_5.png    forgeries_6_5.png
# 2   original_17_8.png  original_17_12.png  forgeries_17_12.png
# 3   original_42_3.png  original_42_14.png  forgeries_42_14.png
# 4   original_1_18.png   original_1_10.png   forgeries_1_10.png
